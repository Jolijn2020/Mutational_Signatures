# %%
import pandas as pd
import random
import re
import numpy as np


signatures = pd.read_csv('cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt', sep='\t')
signatures.set_index('Type', inplace=True)
signatures = signatures[[x for x in signatures.columns if not re.search(r'SBS5$|SBS40.?$',x)]]

orthogonal = dict()
for col_name, col_data in signatures.items():
    other = signatures.drop(columns=col_name)
    other_products = other.apply(lambda x: np.dot(col_data, x))
    orthogonal[col_name] = other_products.mean()

orthogonal = pd.Series(orthogonal).sort_values(ascending=False)

# %%
for signature_count in [8, 15, 25]:
    signature_list = " ".join(orthogonal[:signature_count].index)
    for noise_level in [0.2, 0.4, 0.6]:
        print(signature_list)
        identifier = f"s_{signature_count}_n_{noise_level}"
        # !python SimulateData.py --identifier {identifier} --config "simulated_data/config_v1.json" --signatures_to_extract $signature_list --noise_distribution_avg_perc $noise_level
# Out:
# SBS10a SBS56 SBS10d SBS52 SBS36 SBS91 SBS45 SBS38
# signatures_file_path
# signatures_to_extract
# False
# 0.2
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_8_n_0.2',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.2, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS10a',
#                            'SBS56',
#                            'SBS10d',
#                            'SBS52',
#                            'SBS36',
#                            'SBS91',
#                            'SBS45',
#                            'SBS38']}
# Sucessfully saved simulated data in simulated_data/s_8_n_0.2_GRCh37_10a_56_10d_52_36_91_45_38.csv
# Sucessfully saved meta-data in simulated_data/config_s_8_n_0.2_GRCh37_10a_56_10d_52_36_91_45_38.json
#
#            0    1     2    3     4     5   ...    94   95   96    97    98   99
# Type                                       ...
# A[C>A]A  4500  474  2347  226  6235  6509  ...  1417  520  233  8078  6592  482
# A[C>A]C  4679  509  2368  216  6035  6565  ...  1482  499  217  7902  7286  543
# A[C>A]G  4464  461  2229  207  5778  6136  ...  1412  492  173  7789  6350  514
# A[C>A]T  4703  422  2411  238  6278  6979  ...  1531  528  251  8558  6590  491
# A[C>G]A  4475  434  2254  220  5786  6297  ...  1414  490  225  7762  6338  471
#
# [5 rows x 100 columns]
# SBS10a SBS56 SBS10d SBS52 SBS36 SBS91 SBS45 SBS38
# signatures_file_path
# signatures_to_extract
# False
# 0.4
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_8_n_0.4',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.4, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS10a',
#                            'SBS56',
#                            'SBS10d',
#                            'SBS52',
#                            'SBS36',
#                            'SBS91',
#                            'SBS45',
#                            'SBS38']}
# Sucessfully saved simulated data in simulated_data/s_8_n_0.4_GRCh37_10a_56_10d_52_36_91_45_38.csv
# Sucessfully saved meta-data in simulated_data/config_s_8_n_0.4_GRCh37_10a_56_10d_52_36_91_45_38.json
#
#           0     1     2      3     4     5   ...    94    95     96    97    98   99
# Type                                         ...
# A[C>A]A  922  6228  2881  14773  3473  3770  ...  6592  8816  16861  2708  2887  695
# A[C>A]C  996  5933  2984  15589  3448  3564  ...  6718  8688  18133  2816  2890  687
# A[C>A]G  889  6098  2708  14650  3371  3578  ...  6628  8575  16482  2684  2822  709
# A[C>A]T  974  6383  2759  14810  3579  3705  ...  6775  8791  16836  2808  2871  677
# A[C>G]A  938  6058  2785  14566  3377  3596  ...  6595  8329  16388  2647  2782  670
#
# [5 rows x 100 columns]
# SBS10a SBS56 SBS10d SBS52 SBS36 SBS91 SBS45 SBS38
# signatures_file_path
# signatures_to_extract
# False
# 0.6
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_8_n_0.6',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.6, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS10a',
#                            'SBS56',
#                            'SBS10d',
#                            'SBS52',
#                            'SBS36',
#                            'SBS91',
#                            'SBS45',
#                            'SBS38']}
# Sucessfully saved simulated data in simulated_data/s_8_n_0.6_GRCh37_10a_56_10d_52_36_91_45_38.csv
# Sucessfully saved meta-data in simulated_data/config_s_8_n_0.6_GRCh37_10a_56_10d_52_36_91_45_38.json
#
#            0     1     2     3     4     5   ...    94    95    96    97    98    99
# Type                                         ...
# A[C>A]A  7404  1069  2447  6999  4056  8055  ...  1311  7939  7526  9455  2727  1637
# A[C>A]C  7290  1068  2521  6916  3920  7864  ...  1321  8011  7872  9605  2643  1673
# A[C>A]G  7185  1059  2486  6900  3902  7980  ...  1294  7924  7569  9112  2600  1726
# A[C>A]T  7440  1048  2603  7068  4053  7919  ...  1370  7934  7454  9383  2652  1676
# A[C>G]A  7224  1038  2578  6963  3911  7892  ...  1322  8041  7511  9593  2651  1622
#
# [5 rows x 100 columns]
# SBS10a SBS56 SBS10d SBS52 SBS36 SBS91 SBS45 SBS38 SBS10c SBS14 SBS18 SBS7b SBS7a SBS23 SBS19
# signatures_file_path
# signatures_to_extract
# False
# 0.2
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_15_n_0.2',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.2, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS10a',
#                            'SBS56',
#                            'SBS10d',
#                            'SBS52',
#                            'SBS36',
#                            'SBS91',
#                            'SBS45',
#                            'SBS38',
#                            'SBS10c',
#                            'SBS14',
#                            'SBS18',
#                            'SBS7b',
#                            'SBS7a',
#                            'SBS23',
#                            'SBS19']}
# Sucessfully saved simulated data in simulated_data/s_15_n_0.2_GRCh37_10a_56_10d_52_36_91_45_38_10c_14_18_7b_7a_23_19.csv
# Sucessfully saved meta-data in simulated_data/config_s_15_n_0.2_GRCh37_10a_56_10d_52_36_91_45_38_10c_14_18_7b_7a_23_19.json
#
#           0    1     2    3    4     5   ...   94   95   96    97    98    99
# Type                                     ...
# A[C>A]A  274  828  2278  571  888  2813  ...  244  372  288  1381  1647  3125
# A[C>A]C  332  813  2152  548  997  2875  ...  279  457  286  1400  1726  3294
# A[C>A]G  291  779  2147  526  893  2732  ...  241  449  275  1373  1599  3009
# A[C>A]T  288  837  2169  516  958  2776  ...  269  436  275  1508  1639  2951
# A[C>G]A  287  757  2062  500  956  2806  ...  237  417  251  1423  1545  2884
#
# [5 rows x 100 columns]
# SBS10a SBS56 SBS10d SBS52 SBS36 SBS91 SBS45 SBS38 SBS10c SBS14 SBS18 SBS7b SBS7a SBS23 SBS19
# signatures_file_path
# signatures_to_extract
# False
# 0.4
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_15_n_0.4',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.4, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS10a',
#                            'SBS56',
#                            'SBS10d',
#                            'SBS52',
#                            'SBS36',
#                            'SBS91',
#                            'SBS45',
#                            'SBS38',
#                            'SBS10c',
#                            'SBS14',
#                            'SBS18',
#                            'SBS7b',
#                            'SBS7a',
#                            'SBS23',
#                            'SBS19']}
# Sucessfully saved simulated data in simulated_data/s_15_n_0.4_GRCh37_10a_56_10d_52_36_91_45_38_10c_14_18_7b_7a_23_19.csv
# Sucessfully saved meta-data in simulated_data/config_s_15_n_0.4_GRCh37_10a_56_10d_52_36_91_45_38_10c_14_18_7b_7a_23_19.json
#
#             0    1     2     3     4     5   ...    94    95    96    97   98    99
# Type                                         ...
# A[C>A]A  10235  557  8940  2252  2738  2193  ...  3298  1062  1822  7071  525  3457
# A[C>A]C  10228  591  8973  2206  2808  2133  ...  3414  1074  1690  7209  553  3539
# A[C>A]G   9869  577  8872  2137  2692  2208  ...  3128  1080  1641  7064  545  3243
# A[C>A]T  10204  574  9500  2171  3058  2228  ...  3219  1086  1686  7707  518  3362
# A[C>G]A   9924  569  8799  2133  2718  2199  ...  3174  1039  1748  7133  537  3386
#
# [5 rows x 100 columns]
# SBS10a SBS56 SBS10d SBS52 SBS36 SBS91 SBS45 SBS38 SBS10c SBS14 SBS18 SBS7b SBS7a SBS23 SBS19
# signatures_file_path
# signatures_to_extract
# False
# 0.6
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_15_n_0.6',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.6, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS10a',
#                            'SBS56',
#                            'SBS10d',
#                            'SBS52',
#                            'SBS36',
#                            'SBS91',
#                            'SBS45',
#                            'SBS38',
#                            'SBS10c',
#                            'SBS14',
#                            'SBS18',
#                            'SBS7b',
#                            'SBS7a',
#                            'SBS23',
#                            'SBS19']}
# Sucessfully saved simulated data in simulated_data/s_15_n_0.6_GRCh37_10a_56_10d_52_36_91_45_38_10c_14_18_7b_7a_23_19.csv
# Sucessfully saved meta-data in simulated_data/config_s_15_n_0.6_GRCh37_10a_56_10d_52_36_91_45_38_10c_14_18_7b_7a_23_19.json
#
#           0    1    2     3     4     5   ...    94     95   96   97    98    99
# Type                                      ...
# A[C>A]A  871  886  747  6326  6985  2325  ...  3441  11754  964  880  1896  1221
# A[C>A]C  918  935  850  6370  6797  2360  ...  3634  11092  962  850  1890  1196
# A[C>A]G  904  933  840  6262  6589  2408  ...  3490  11357  924  902  1875  1147
# A[C>A]T  901  944  779  6363  6674  2613  ...  3498  11522  990  871  2002  1143
# A[C>G]A  863  899  824  6394  6478  2428  ...  3488  11255  975  856  1949  1150
#
# [5 rows x 100 columns]
# SBS10a SBS56 SBS10d SBS52 SBS36 SBS91 SBS45 SBS38 SBS10c SBS14 SBS18 SBS7b SBS7a SBS23 SBS19 SBS30 SBS11 SBS95 SBS20 SBS10b SBS58 SBS2 SBS15 SBS42 SBS4
# signatures_file_path
# signatures_to_extract
# False
# 0.2
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_25_n_0.2',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.2, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS10a',
#                            'SBS56',
#                            'SBS10d',
#                            'SBS52',
#                            'SBS36',
#                            'SBS91',
#                            'SBS45',
#                            'SBS38',
#                            'SBS10c',
#                            'SBS14',
#                            'SBS18',
#                            'SBS7b',
#                            'SBS7a',
#                            'SBS23',
#                            'SBS19',
#                            'SBS30',
#                            'SBS11',
#                            'SBS95',
#                            'SBS20',
#                            'SBS10b',
#                            'SBS58',
#                            'SBS2',
#                            'SBS15',
#                            'SBS42',
#                            'SBS4']}
# Sucessfully saved simulated data in simulated_data/s_25_n_0.2_GRCh37_10a_56_10d_52_36_91_45_38_10c_14_18_7b_7a_23_19_30_11_95_20_10b_58_2_15_42_4.csv
# Sucessfully saved meta-data in simulated_data/config_s_25_n_0.2_GRCh37_10a_56_10d_52_36_91_45_38_10c_14_18_7b_7a_23_19_30_11_95_20_10b_58_2_15_42_4.json
#
#           0    1     2    3     4      5   ...   94    95    96   97    98    99
# Type                                       ...
# A[C>A]A  480  804  8050  758  4726  10746  ...  360  1110  2011  409  6126  4638
# A[C>A]C  452  762  7783  709  5489   8849  ...  319  1045  2038  403  6267  4697
# A[C>A]G  498  773  7511  697  4781   8325  ...  354   979  2002  382  6015  4648
# A[C>A]T  491  754  8179  773  4811   8655  ...  335  1010  2075  427  6203  4752
# A[C>G]A  455  820  7573  700  4883   8713  ...  318   948  1836  395  6013  4702
#
# [5 rows x 100 columns]
# SBS10a SBS56 SBS10d SBS52 SBS36 SBS91 SBS45 SBS38 SBS10c SBS14 SBS18 SBS7b SBS7a SBS23 SBS19 SBS30 SBS11 SBS95 SBS20 SBS10b SBS58 SBS2 SBS15 SBS42 SBS4
# signatures_file_path
# signatures_to_extract
# False
# 0.4
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_25_n_0.4',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.4, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS10a',
#                            'SBS56',
#                            'SBS10d',
#                            'SBS52',
#                            'SBS36',
#                            'SBS91',
#                            'SBS45',
#                            'SBS38',
#                            'SBS10c',
#                            'SBS14',
#                            'SBS18',
#                            'SBS7b',
#                            'SBS7a',
#                            'SBS23',
#                            'SBS19',
#                            'SBS30',
#                            'SBS11',
#                            'SBS95',
#                            'SBS20',
#                            'SBS10b',
#                            'SBS58',
#                            'SBS2',
#                            'SBS15',
#                            'SBS42',
#                            'SBS4']}
# Sucessfully saved simulated data in simulated_data/s_25_n_0.4_GRCh37_10a_56_10d_52_36_91_45_38_10c_14_18_7b_7a_23_19_30_11_95_20_10b_58_2_15_42_4.csv
# Sucessfully saved meta-data in simulated_data/config_s_25_n_0.4_GRCh37_10a_56_10d_52_36_91_45_38_10c_14_18_7b_7a_23_19_30_11_95_20_10b_58_2_15_42_4.json
#
#           0    1     2    3      4     5   ...    94    95   96     97   98    99
# Type                                       ...
# A[C>A]A  802  445  1193  418  11450  7953  ...  1819  1325  408  10530  465  1695
# A[C>A]C  801  432  1165  441  11093  8027  ...  1829  1230  392  10582  443  1728
# A[C>A]G  802  419  1135  433  10879  7662  ...  1772  1183  432  10174  442  1692
# A[C>A]T  765  452  1202  423  11327  8021  ...  1864  1396  425  10436  461  1766
# A[C>G]A  758  438  1235  412  10984  7705  ...  1792  1248  468  10115  446  1742
#
# [5 rows x 100 columns]
# SBS10a SBS56 SBS10d SBS52 SBS36 SBS91 SBS45 SBS38 SBS10c SBS14 SBS18 SBS7b SBS7a SBS23 SBS19 SBS30 SBS11 SBS95 SBS20 SBS10b SBS58 SBS2 SBS15 SBS42 SBS4
# signatures_file_path
# signatures_to_extract
# False
# 0.6
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_25_n_0.6',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.6, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS10a',
#                            'SBS56',
#                            'SBS10d',
#                            'SBS52',
#                            'SBS36',
#                            'SBS91',
#                            'SBS45',
#                            'SBS38',
#                            'SBS10c',
#                            'SBS14',
#                            'SBS18',
#                            'SBS7b',
#                            'SBS7a',
#                            'SBS23',
#                            'SBS19',
#                            'SBS30',
#                            'SBS11',
#                            'SBS95',
#                            'SBS20',
#                            'SBS10b',
#                            'SBS58',
#                            'SBS2',
#                            'SBS15',
#                            'SBS42',
#                            'SBS4']}
# Sucessfully saved simulated data in simulated_data/s_25_n_0.6_GRCh37_10a_56_10d_52_36_91_45_38_10c_14_18_7b_7a_23_19_30_11_95_20_10b_58_2_15_42_4.csv
# Sucessfully saved meta-data in simulated_data/config_s_25_n_0.6_GRCh37_10a_56_10d_52_36_91_45_38_10c_14_18_7b_7a_23_19_30_11_95_20_10b_58_2_15_42_4.json
#
#             0      1     2     3     4   ...    95   96    97    98     99
# Type                                     ...
# A[C>A]A  17133  27891  5891  6637  6405  ...  5621  935  2813  3772  20784
# A[C>A]C  17103  27033  5573  6745  6304  ...  5769  887  2835  3717  22023
# A[C>A]G  16989  26414  5643  6603  6249  ...  5782  914  2784  3762  20616
# A[C>A]T  17418  27776  5656  6743  6552  ...  5698  910  2897  3715  20431
# A[C>G]A  17188  26742  5818  6462  6384  ...  5597  891  2796  3681  20809
#
# [5 rows x 100 columns]
