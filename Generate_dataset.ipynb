# %%
import pandas as pd
import random
import re
import numpy as np


signatures = pd.read_csv('cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt', sep='\t')
signatures.set_index('Type', inplace=True)
signatures = signatures[[x for x in signatures.columns if not re.search(r'SBS5$|SBS40.?$',x)]]

orthogonal = dict()
for col_name, col_data in signatures.items():
    other = signatures.drop(columns=col_name)
    other_products = other.apply(lambda x: np.dot(col_data, x))
    orthogonal[col_name] = other_products.mean()

orthogonal = pd.Series(orthogonal).sort_values() #should be ascending as lower dot products are more dissimilar

# %%
for signature_count in [8, 15, 25]:
    signature_list = " ".join(orthogonal[:signature_count].index)
    print(signature_list)

    for noise_level in [0.02, 0.04, 0.06]:
        identifier = f"s_{signature_count}_n_{noise_level}"
        # !python SimulateData.py --identifier {identifier} --config "simulated_data/config_v1.json" --signatures_to_extract $signature_list --noise_distribution_avg_perc $noise_level
# Out:
# SBS17b SBS86 SBS98 SBS39 SBS22a SBS43 SBS17a SBS13
# signatures_file_path
# signatures_to_extract
# False
# 0.02
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_8_n_0.02',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.02, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS17b',
#                            'SBS86',
#                            'SBS98',
#                            'SBS39',
#                            'SBS22a',
#                            'SBS43',
#                            'SBS17a',
#                            'SBS13']}
# Sucessfully saved simulated data in simulated_data/s_8_n_0.02_GRCh37_17b_86_98_39_22a_43_17a_13.csv
# Sucessfully saved meta-data in simulated_data/config_s_8_n_0.02_GRCh37_17b_86_98_39_22a_43_17a_13.json
#
#            0    1     2    3    4    5    6   ...  93  94   95  96   97   98   99
# Type                                          ...
# A[C>A]A   648   89  1035  649  174  370  466  ...  24  71  769  44  201  172  373
# A[C>A]C   634   74   838  593  142  345  343  ...  21  56  709  39  114  190  358
# A[C>A]G   555  107   948  762  138  486  294  ...  27  72  980  35  101  163  354
# A[C>A]T   657   82   920  571  150  303  333  ...  24  68  665  34  105  169  377
# A[C>G]A  1762  159   978  686  303  731  710  ...  29  79  753  78  109  396  615
#
# [5 rows x 100 columns]
# signatures_file_path
# signatures_to_extract
# False
# 0.04
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_8_n_0.04',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.04, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS17b',
#                            'SBS86',
#                            'SBS98',
#                            'SBS39',
#                            'SBS22a',
#                            'SBS43',
#                            'SBS17a',
#                            'SBS13']}
# Sucessfully saved simulated data in simulated_data/s_8_n_0.04_GRCh37_17b_86_98_39_22a_43_17a_13.csv
# Sucessfully saved meta-data in simulated_data/config_s_8_n_0.04_GRCh37_17b_86_98_39_22a_43_17a_13.json
#
#            0     1    2    3    4    5   ...   94    95   96   97   98   99
# Type                                     ...
# A[C>A]A  1473  1493  205  649  134  490  ...  575  1046  352  119  164  134
# A[C>A]C  1353  1456  188  575  119  505  ...  477   889  314   95  146  101
# A[C>A]G  1272  1285  140  579  125  590  ...  421   843  333   82  128  122
# A[C>A]T  1381  1450  164  577  105  464  ...  452   837  325   76  133  112
# A[C>G]A  2126  2008  145  616  178  784  ...  455   767  354   68  222  137
#
# [5 rows x 100 columns]
# signatures_file_path
# signatures_to_extract
# False
# 0.06
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_8_n_0.06',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.06, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS17b',
#                            'SBS86',
#                            'SBS98',
#                            'SBS39',
#                            'SBS22a',
#                            'SBS43',
#                            'SBS17a',
#                            'SBS13']}
# Sucessfully saved simulated data in simulated_data/s_8_n_0.06_GRCh37_17b_86_98_39_22a_43_17a_13.csv
# Sucessfully saved meta-data in simulated_data/config_s_8_n_0.06_GRCh37_17b_86_98_39_22a_43_17a_13.json
#
#           0    1    2    3     4    5   ...    94  95    96   97   98    99
# Type                                    ...
# A[C>A]A  176  455  697  205  1477  434  ...   944  87  2388  304   83  1110
# A[C>A]C  202  470  587  149  1532  415  ...   940  87  1961  308   71   861
# A[C>A]G  158  428  555  140  1888  519  ...   852  79  1886  346   78   819
# A[C>A]T  179  440  544  168  1466  369  ...   906  85  1915  307   76   875
# A[C>G]A  146  453  551  209  1578  434  ...  1225  95  1980  282  137   832
#
# [5 rows x 100 columns]
# SBS17b SBS86 SBS98 SBS39 SBS22a SBS43 SBS17a SBS13 SBS54 SBS33 SBS21 SBS59 SBS60 SBS87 SBS37
# signatures_file_path
# signatures_to_extract
# False
# 0.02
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_15_n_0.02',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.02, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS17b',
#                            'SBS86',
#                            'SBS98',
#                            'SBS39',
#                            'SBS22a',
#                            'SBS43',
#                            'SBS17a',
#                            'SBS13',
#                            'SBS54',
#                            'SBS33',
#                            'SBS21',
#                            'SBS59',
#                            'SBS60',
#                            'SBS87',
#                            'SBS37']}
# Sucessfully saved simulated data in simulated_data/s_15_n_0.02_GRCh37_17b_86_98_39_22a_43_17a_13_54_33_21_59_60_87_37.csv
# Sucessfully saved meta-data in simulated_data/config_s_15_n_0.02_GRCh37_17b_86_98_39_22a_43_17a_13_54_33_21_59_60_87_37.json
#
#           0    1    2   3   4    5   6   ...  93  94   95    96   97   98   99
# Type                                     ...
# A[C>A]A  146  673  512  50  47  100  62  ...  40  30  294  1080  269   76  288
# A[C>A]C  143  707  431  48  51   93  46  ...  29  28  229   989  292   69  255
# A[C>A]G  134  690  724  40  40   84  46  ...  36  45  229   915  260   59  277
# A[C>A]T  126  621  418  62  45   83  40  ...  26  17  270  1393  285   73  269
# A[C>G]A  145  642  476  53  38   91  51  ...  43  61  434  1635  311  123  300
#
# [5 rows x 100 columns]
# signatures_file_path
# signatures_to_extract
# False
# 0.04
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_15_n_0.04',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.04, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS17b',
#                            'SBS86',
#                            'SBS98',
#                            'SBS39',
#                            'SBS22a',
#                            'SBS43',
#                            'SBS17a',
#                            'SBS13',
#                            'SBS54',
#                            'SBS33',
#                            'SBS21',
#                            'SBS59',
#                            'SBS60',
#                            'SBS87',
#                            'SBS37']}
# Sucessfully saved simulated data in simulated_data/s_15_n_0.04_GRCh37_17b_86_98_39_22a_43_17a_13_54_33_21_59_60_87_37.csv
# Sucessfully saved meta-data in simulated_data/config_s_15_n_0.04_GRCh37_17b_86_98_39_22a_43_17a_13_54_33_21_59_60_87_37.json
#
#          0    1    2    3   4     5     6   ...   93   94    95  96   97    98   99
# Type                                        ...
# A[C>A]A  91  107  101  290  83   672  1470  ...  556   90  1723  51  103  1882  475
# A[C>A]C  70   94  105  261  63   685  1473  ...  490   95  1687  51  100  1935  468
# A[C>A]G  72  125  106  266  67   616  1351  ...  533  109  1604  49   92  1766  421
# A[C>A]T  86   83  113  287  60   635  1457  ...  507   83  1736  47   92  2208  432
# A[C>G]A  99  101  116  271  87  1024  2021  ...  732   92  2867  70  210  2919  645
#
# [5 rows x 100 columns]
# signatures_file_path
# signatures_to_extract
# False
# 0.06
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_15_n_0.06',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.06, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS17b',
#                            'SBS86',
#                            'SBS98',
#                            'SBS39',
#                            'SBS22a',
#                            'SBS43',
#                            'SBS17a',
#                            'SBS13',
#                            'SBS54',
#                            'SBS33',
#                            'SBS21',
#                            'SBS59',
#                            'SBS60',
#                            'SBS87',
#                            'SBS37']}
# Sucessfully saved simulated data in simulated_data/s_15_n_0.06_GRCh37_17b_86_98_39_22a_43_17a_13_54_33_21_59_60_87_37.csv
# Sucessfully saved meta-data in simulated_data/config_s_15_n_0.06_GRCh37_17b_86_98_39_22a_43_17a_13_54_33_21_59_60_87_37.json
#
#           0     1    2    3     4    5   ...   94    95    96   97   98    99
# Type                                     ...
# A[C>A]A  163  2794  294  126  2137  138  ...  446  1556  1495   91  397  2055
# A[C>A]C  158  2664  271  115  1990  134  ...  384  1503  1442  104  356  2051
# A[C>A]G  157  2668  282  102  1855  143  ...  370  1471  1391   98  382  1942
# A[C>A]T  136  2698  305  109  1835  147  ...  380  1556  1422   77  369  1978
# A[C>G]A  139  3249  352  146  1895  141  ...  422  2267  1455   84  520  2913
#
# [5 rows x 100 columns]
# SBS17b SBS86 SBS98 SBS39 SBS22a SBS43 SBS17a SBS13 SBS54 SBS33 SBS21 SBS59 SBS60 SBS87 SBS37 SBS96 SBS28 SBS55 SBS99 SBS26 SBS3 SBS1 SBS12 SBS93 SBS22b
# signatures_file_path
# signatures_to_extract
# False
# 0.02
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_25_n_0.02',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.02, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS17b',
#                            'SBS86',
#                            'SBS98',
#                            'SBS39',
#                            'SBS22a',
#                            'SBS43',
#                            'SBS17a',
#                            'SBS13',
#                            'SBS54',
#                            'SBS33',
#                            'SBS21',
#                            'SBS59',
#                            'SBS60',
#                            'SBS87',
#                            'SBS37',
#                            'SBS96',
#                            'SBS28',
#                            'SBS55',
#                            'SBS99',
#                            'SBS26',
#                            'SBS3',
#                            'SBS1',
#                            'SBS12',
#                            'SBS93',
#                            'SBS22b']}
# Sucessfully saved simulated data in simulated_data/s_25_n_0.02_GRCh37_17b_86_98_39_22a_43_17a_13_54_33_21_59_60_87_37_96_28_55_99_26_3_1_12_93_22b.csv
# Sucessfully saved meta-data in simulated_data/config_s_25_n_0.02_GRCh37_17b_86_98_39_22a_43_17a_13_54_33_21_59_60_87_37_96_28_55_99_26_3_1_12_93_22b.json
#
#          0   1    2    3    4    5   6   ...   93   94  95  96    97   98  99
# Type                                     ...
# A[C>A]A  72  34  488  581  160  345  91  ...  867  416  38  66   771  190  34
# A[C>A]C  62  37  328  587  148  323  85  ...  846  440  30  61   713  198  28
# A[C>A]G  65  24  250  506   79  355  71  ...  776  396  29  62   680  160  44
# A[C>A]T  77  32  273  557  138  282  74  ...  822  405  21  51   730  173  30
# A[C>G]A  68  43  245  526  160  337  87  ...  816  436  27  57  1398  190  36
#
# [5 rows x 100 columns]
# signatures_file_path
# signatures_to_extract
# False
# 0.04
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_25_n_0.04',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.04, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS17b',
#                            'SBS86',
#                            'SBS98',
#                            'SBS39',
#                            'SBS22a',
#                            'SBS43',
#                            'SBS17a',
#                            'SBS13',
#                            'SBS54',
#                            'SBS33',
#                            'SBS21',
#                            'SBS59',
#                            'SBS60',
#                            'SBS87',
#                            'SBS37',
#                            'SBS96',
#                            'SBS28',
#                            'SBS55',
#                            'SBS99',
#                            'SBS26',
#                            'SBS3',
#                            'SBS1',
#                            'SBS12',
#                            'SBS93',
#                            'SBS22b']}
# Sucessfully saved simulated data in simulated_data/s_25_n_0.04_GRCh37_17b_86_98_39_22a_43_17a_13_54_33_21_59_60_87_37_96_28_55_99_26_3_1_12_93_22b.csv
# Sucessfully saved meta-data in simulated_data/config_s_25_n_0.04_GRCh37_17b_86_98_39_22a_43_17a_13_54_33_21_59_60_87_37_96_28_55_99_26_3_1_12_93_22b.json
#
#           0    1   2    3    4     5   6   ...   93   94   95   96  97    98   99
# Type                                       ...
# A[C>A]A  646  165  62  411  278  1159  36  ...  100  104  663   92  76  1101  205
# A[C>A]C  587  138  56  392  258  1170  53  ...  103  111  716  101  72  1065  198
# A[C>A]G  557  127  64  364  226  1102  39  ...   95  107  664  128  44   998  201
# A[C>A]T  571  144  75  390  263  1095  40  ...  115  111  675   98  70  1084  223
# A[C>G]A  915  150  50  563  430  1149  42  ...  121   99  667  156  71  1657  184
#
# [5 rows x 100 columns]
# signatures_file_path
# signatures_to_extract
# False
# 0.06
# {'counts_distribution': {'distribution': 'logscale', 'max': 50000, 'min': 1000},
#  'identifier': 's_25_n_0.06',
#  'n_samples': 100,
#  'noise_distribution': {'avg_perc': 0.06, 'distribution': 'poisson'},
#  'sample_signature_distribution': {'distribution': 'uniform',
#                                    'max': 2,
#                                    'min': 0.5,
#                                    'n_sign_active': 2,
#                                    'sign_active_prob': 0.4,
#                                    'use_sign_active_prob': False},
#  'save_dir': 'simulated_data',
#  'signatures_file_path': 'cosmic_signatures/COSMIC_v3.4_SBS_GRCh37.txt',
#  'signatures_to_extract': ['SBS17b',
#                            'SBS86',
#                            'SBS98',
#                            'SBS39',
#                            'SBS22a',
#                            'SBS43',
#                            'SBS17a',
#                            'SBS13',
#                            'SBS54',
#                            'SBS33',
#                            'SBS21',
#                            'SBS59',
#                            'SBS60',
#                            'SBS87',
#                            'SBS37',
#                            'SBS96',
#                            'SBS28',
#                            'SBS55',
#                            'SBS99',
#                            'SBS26',
#                            'SBS3',
#                            'SBS1',
#                            'SBS12',
#                            'SBS93',
#                            'SBS22b']}
# Sucessfully saved simulated data in simulated_data/s_25_n_0.06_GRCh37_17b_86_98_39_22a_43_17a_13_54_33_21_59_60_87_37_96_28_55_99_26_3_1_12_93_22b.csv
# Sucessfully saved meta-data in simulated_data/config_s_25_n_0.06_GRCh37_17b_86_98_39_22a_43_17a_13_54_33_21_59_60_87_37_96_28_55_99_26_3_1_12_93_22b.json
#
#            0     1     2     3    4    5   ...    94    95    96  97   98    99
# Type                                       ...
# A[C>A]A  1209  2913  2922  1583  172  321  ...  3517  1132  2303  69  185  1511
# A[C>A]C  1064  2901  2887  1618  202  282  ...  3348  1082  2290  70  177  1368
# A[C>A]G  1144  3437  2683  1545  170  273  ...  2895  1088  2271  67  200  1394
# A[C>A]T  1158  2931  2702  1556  193  275  ...  3354  1119  2302  74  179  1389
# A[C>G]A  1166  2910  4135  1973  240  367  ...  3382  1454  3082  73  154  1714
#
# [5 rows x 100 columns]
